# %%
import cplot
import numpy

# %%
cplot.show(numpy.exp, -2, +2, -2, +2, 100, 100)

# %%
cplot.show(lambda z: z / abs(z), -2, +2, -2, +2, 100, 100)

# %% [markdown]
# # CPlot package info here
# * https://github.com/nschloe/cplot
